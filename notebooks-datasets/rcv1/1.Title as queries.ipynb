# %% [markdown]
# # How we do it in Barbera1 - RCV1
#
# We use Terrier 4.2. with RCV1 dataset
#
# The script we used to convert JSON to TERRIER files did not include TITLE, so we indexed just the BODY.
# We will use the TITLE (unprocessed) as query.
#
# Index properties:
# - we have only BODY
# - we have a positional index: block.indexing=True
#
#
# We apply BM25Classic and BM25Passage.
# - for BM25Passage we divide the file in 10 equal parts
# - for BM25P we apply the weights from our statistical analysis of the text on (TFIDF and IDF) - see notebook High IDF Terms in Signal collection.ipynb
# - we evaluate: P@1, NDCG@k, Recall@k

# %% [markdown]
# ## 1. Creating queries

# %%
# %load_ext autoreload
# %autoreload 2


from elasticsearch import Elasticsearch, RequestError
import json
import pandas as pd
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset = pd.read_json("../data/rcv1_news.json", lines=True)
dataset.shape[0]

dataset
# Out:
#                                                categories  \
# 0                             [E11, ECAT, M11, M12, MCAT]
# 1                                             [C24, CCAT]
# 2                [C15, C151, CCAT, E41, ECAT, GCAT, GJOB]
# 3                                       [C15, C151, CCAT]
# 4                                        [C11, C22, CCAT]
# 5                                             [M14, MCAT]
# 6                        [M11, M12, M13, M132, M14, MCAT]
# 7                                             [C22, CCAT]
# 8                                             [E14, ECAT]
# 9                                [C12, CCAT, GCAT, GCRIM]
# 10           [C13, C31, C42, CCAT, E41, ECAT, GCAT, GJOB]
# 11                                            [M11, MCAT]
# 12                           [E12, ECAT, M13, M131, MCAT]
# 13                               [C12, CCAT, GCAT, GCRIM]
# 14                                            [M11, MCAT]
# 15                                            [M11, MCAT]
# 16                                      [C18, C181, CCAT]
# 17                                           [GCAT, GPOL]
# 18      [C13, C42, CCAT, E14, E41, ECAT, GCAT, GJOB, G...
# 19                               [C12, CCAT, GCAT, GCRIM]
# 20                               [C12, CCAT, GCAT, GCRIM]
# 21                                      [M14, M143, MCAT]
# 22                                            [E12, ECAT]
# 23                     [E51, E512, ECAT, G15, G158, GCAT]
# 24                                           [GCAT, GDIP]
# 25                               [C12, CCAT, GCAT, GCRIM]
# 26                                    [GCAT, GPOL, GVOTE]
# 27                     [C42, CCAT, E41, ECAT, GCAT, GJOB]
# 28                                            [M11, MCAT]
# 29                                      [C15, C152, CCAT]
# ...                                                   ...
# 804384                                   [C13, C21, CCAT]
# 804385                                  [C15, C151, CCAT]
# 804386                                  [M14, M143, MCAT]
# 804387                                        [C11, CCAT]
# 804388                                  [C15, C151, CCAT]
# 804389                                  [C15, C151, CCAT]
# 804390                                  [C15, C151, CCAT]
# 804391                                  [C41, C411, CCAT]
# 804392                              [C13, C22, C34, CCAT]
# 804393                                        [M11, MCAT]
# 804394                                        [C21, CCAT]
# 804395                                  [M14, M143, MCAT]
# 804396                                        [C22, CCAT]
# 804397                       [C24, CCAT, E21, E211, ECAT]
# 804398                                  [C15, C151, CCAT]
# 804399                                 [CCAT, GCAT, GDIS]
# 804400                                  [E21, E212, ECAT]
# 804401                                  [E21, E212, ECAT]
# 804402                                  [M14, M143, MCAT]
# 804403                                      [GCAT, GCRIM]
# 804404                                  [C15, C152, CCAT]
# 804405                 [C42, CCAT, E41, ECAT, GCAT, GJOB]
# 804406                                  [C15, C151, CCAT]
# 804407                                  [M14, M141, MCAT]
# 804408                                  [C18, C182, CCAT]
# 804409                             [C18, C181, C41, CCAT]
# 804410                       [C15, C152, CCAT, M11, MCAT]
# 804411                 [C12, C13, C24, CCAT, GCAT, GCRIM]
# 804412                                  [C41, C411, CCAT]
# 804413                                  [M14, M141, MCAT]
#
#                                                   content       date  \
# 0       Emerging evidence that Mexico's economy was ba... 1996-08-20
# 1       Chrysler Corp. Tuesday announced $380 million ... 1996-08-20
# 2       CompuServe Corp. Tuesday reported a surprising... 1996-08-20
# 3       CompuServe Corp. Tuesday reported a surprising... 1996-08-20
# 4       If dining at Planet Hollywood made you feel li... 1996-08-20
# 5       Hog prices fell Tuesday after government slaug... 1996-08-20
# 6       Blue-chip stocks rallied Tuesday after the Fed... 1996-08-20
# 7       Sprint Corp. Tuesday announced plans to offer ... 1996-08-20
# 8       Shoppers are loading up this year on perennial... 1996-08-20
# 9       Kansas and Arizona filed lawsuits against some... 1996-08-20
# 10      The higher minimum wage signed into law Tuesda... 1996-08-20
# 11      Blue-chip stocks bounded higher Tuesday as the... 1996-08-20
# 12      By Rich Miller, Economics Correspondent\nThe F... 1996-08-20
# 13      Ronald Sandler, chief executive of Lloyd's of ... 1996-08-20
# 14      The following were the most active issues in N... 1996-08-20
# 15      Prices on the New York Stock Exchange closed m... 1996-08-20
# 16      Columbia/HCA Healthcare Corp.'s proposed $299.... 1996-08-20
# 17      Gulf War hero Colin Powell lent his prestige a... 1996-08-20
# 18      President Bill Clinton gave millions of Americ... 1996-08-20
# 19      Another liability challenge to the tobacco ind... 1996-08-20
# 20      Kansas and Arizona filed lawsuits Tuesday agai... 1996-08-20
# 21      World oil prices slipped on Tuesday in a marke... 1996-08-20
# 22      By Rich Miller, Economics Correspondent\nThe (... 1996-08-20
# 23      The United States may seek an informal allianc... 1996-08-20
# 24      Japanese Prime Minister Ryutaro Hashimoto arri... 1996-08-20
# 25      Lloyd's of London chief executive Ron Sandler ... 1996-08-20
# 26      Gulf War hero Colin Powell lent his prestige a... 1996-08-20
# 27      The two main unions representing German retail... 1996-08-20
# 28      Britain's FTSE 100 stock index, which sank to ... 1996-08-20
# 29      The Trocadero entertainment complex in the hea... 1996-08-20
# ...                                                   ...        ...
# 804384  A U.S. government-financed radio station repor... 1997-08-19
# 804385  THE WET SEAL, INC.\n\t\t\t\tSELECTED FINANCIAL... 1997-08-19
# 804386  U.S. spot fuel oil prices mostly held steady a... 1997-08-19
# 804387  Akorn Inc  on Tuesday said it completed reloca... 1997-08-19
# 804388  Condensed Income Statements\n\t\t\t For the Qu... 1997-08-19
# 804389  MARVEL ENTERTAINMENT GROUP, INC.\n\t\t\t\t  (D... 1997-08-19
# 804390  Dell Computer Corp. said Tuesday that second-q... 1997-08-19
# 804391  Versant Object Technology Corp said Tuesday it... 1997-08-19
# 804392  Ameritech Corp said Tuesday it will review an ... 1997-08-19
# 804393  Blue-chip stocks raced higher for the second d... 1997-08-19
# 804394  This year's healthy precipitation and extra re... 1997-08-19
# 804395  NYMEX Henry Hub natgas futures mostly ended up... 1997-08-19
# 804396  American Airlines said Tuesday it will soon be... 1997-08-19
# 804397  The Minnesota Twins, an American League baseba... 1997-08-19
# 804398  Medtronic Inc., the largest U.S. manufacturer ... 1997-08-19
# 804399  Federal investigators said  Tuesday that ValuJ... 1997-08-19
# 804400  The International Monetary Fund's board will d... 1997-08-19
# 804401  The International Monetary Fund has exchanged ... 1997-08-19
# 804402  Koch Oil said it raised the price it will pay ... 1997-08-19
# 804403  The videotaped abuse of convicts in southeast ... 1997-08-19
# 804404  The Beard Co said Tuesday that it has reached ... 1997-08-19
# 804405  The Teamsters union's success in waging the na... 1997-08-19
# 804406  Dell Computer Corp said Tuesday its second qua... 1997-08-19
# 804407  Rains subsided across most areas the U.S. Nort... 1997-08-19
# 804408  Jacor Communications Inc said Tuesday it has s... 1997-08-19
# 804409  Wall Street investor Carl Icahn said on Tuesda... 1997-08-19
# 804410  The New York Stock Exchange said Tuesday that ... 1997-08-19
# 804411  A Michigan Indian tribe announced Tuesday it h... 1997-08-19
# 804412  Liuski International Inc said Tuesday that Chi... 1997-08-19
# 804413  Grain and oilseed exports reported by USDA and... 1997-08-19
#
#                                                  headline      id lang  \
# 0       Recovery excitement brings Mexican markets to ...    2286   en
# 1        Chrysler plans new investments in Latin America.    2287   en
# 2            CompuServe reports loss, cutting work force.    2288   en
# 3            CompuServe reports loss, cutting work force.    2289   en
# 4                  Planet Hollywood launches credit card.    2290   en
# 5       Hog prices tumble as supplies increase, cocoa ...    2291   en
# 6       Blue chips end up as Fed keeps interest rates ...    2292   en
# 7       Sprint to offer consumer Internet access service.    2293   en
# 8                          Back-to-school spending is up.    2294   en
# 9       Kansas, Arizona add to suits against tobacco f...    2295   en
# 10       Chains may raise prices after minimum wage hike.    2296   en
# 11      Blue chips end up as Fed keeps interest rates ...    2297   en
# 12      U.S. Federal Reserve holds interest rates steady.    2298   en
# 13       Lloyd's CEO questioned in recovery suit in U.S..    2299   en
# 14                  Most active stocks in Nasdaq trading.    2300   en
# 15                                 NYSE closing averages.    2301   en
# 16      Ohio Blue Cross approves $299.5 mln Columbia/H...    2302   en
# 17      War hero Colin Powell hits road with Dole camp...    2303   en
# 18       Clinton signs law raising minimum wage to $5.15.    2304   en
# 19             Decision nears on Indiana tobacco lawsuit.    2305   en
# 20        Kansas files lawsuit against tobacco companies.    2306   en
# 21         Oil prices slip as refiners shop for bargains.    2307   en
# 22             Fed decides to keep interest rates steady.    2308   en
# 23             Japan, EU may aid U.S. in ag trade reform.    2309   en
# 24             Japanese prime minister arrives in Mexico.    2310   en
# 25                 Lloyd's chief undergoes U.S. grilling.    2311   en
# 26            War hero Colin Powell boosts Dole campaign.    2312   en
# 27      German unions split on tactics in retail pay t...    2313   en
# 28      British FTSE index closes at record 3,883 points.    2314   en
# 29                Trocadero expects tripling of revenues.    2315   en
# ...                                                   ...     ...  ...
# 804384  U.S.-based radio says broadcasts to China jammed.  808692   en
# 804385                       TABLE - Wet Seal Q2 results.  808693   en
# 804386  U.S. spot resids mostly hold with firm gas, cr...  808694   en
# 804387  Akorn completes relocation of offices to Illin...  808695   en
# 804388              TABLE - Longs Drug Stores Q2 results.  808696   en
# 804389       TABLE - Marvel Entertainment Q2 loss widens.  808697   en
# 804390  Dell earnings double in latest quarter, beatin...  808698   en
# 804391         Versant begins search for chief executive.  808699   en
# 804392         Ameritech to review FCC order, may refile.  808700   en
# 804393  Blue-chip stocks surge after Fed holds rates s...  808701   en
# 804394  Extra Colo. River flows lift power output 15 pct.  808702   en
# 804395   NYMEX Hub natgas ends up sharply on firmer cash.  808703   en
# 804396     American Airlines starts new US-Mexico routes.  808704   en
# 804397  Minnesota official sees low odds for Twins sta...  808705   en
# 804398   Medtronic profits bolstered by ICD sales growth.  808706   en
# 804399  ValuJet crash could have been avoided-U.S. age...  808707   en
# 804400  IMF board to discuss Thai loan package on Wedn...  808708   en
# 804401   No date yet for new Turkey-IMF talks-IMF source.  808709   en
# 804402  Koch Oil raises U.S. posted crude oil 25 cts/bbl.  808710   en
# 804403  Texas abuse tape spurs unease over private pri...  808711   en
# 804404        Beard Co to post $10.95 mln gain from sale.  808712   en
# 804405  Teamsters-UPS deal a boost to U.S. labor - ana...  808713   en
# 804406        Dell Q2 earnings double, topping estimates.  808714   en
# 804407  U.S. Spring/White Wheat - Fields drying out sl...  808715   en
# 804408         Jacor buys Cleveland sports radio station.  808716   en
# 804409              Icahn seeks three Panaco board seats.  808717   en
# 804410                               NYSE Unavailables -.  808718   en
# 804411   Tribe drops bid to stop Detroit casino planning.  808719   en
# 804412                   Liuski names new president, CFO.  808720   en
# 804413          Export Business - Grain/oilseeds complex.  808721   en
#
#                                                     title
# 0       MEXICO: Recovery excitement brings Mexican mar...
# 1       USA: Chrysler plans new investments in Latin A...
# 2       USA: CompuServe reports loss, cutting work force.
# 3       USA: CompuServe reports loss, cutting work force.
# 4             USA: Planet Hollywood launches credit card.
# 5       USA: Hog prices tumble as supplies increase, c...
# 6       USA: Blue chips end up as Fed keeps interest r...
# 7       USA: Sprint to offer consumer Internet access ...
# 8                     USA: Back-to-school spending is up.
# 9       USA: Kansas, Arizona add to suits against toba...
# 10      USA: Chains may raise prices after minimum wag...
# 11      USA: Blue chips end up as Fed keeps interest r...
# 12      USA: U.S. Federal Reserve holds interest rates...
# 13      USA: Lloyd's CEO questioned in recovery suit i...
# 14             USA: Most active stocks in Nasdaq trading.
# 15                            USA: NYSE closing averages.
# 16      USA: Ohio Blue Cross approves $299.5 mln Colum...
# 17      USA: War hero Colin Powell hits road with Dole...
# 18      USA: Clinton signs law raising minimum wage to...
# 19        USA: Decision nears on Indiana tobacco lawsuit.
# 20      USA: Kansas files lawsuit against tobacco comp...
# 21      UK: Oil prices slip as refiners shop for barga...
# 22        USA: Fed decides to keep interest rates steady.
# 23        USA: Japan, EU may aid U.S. in ag trade reform.
# 24      MEXICO: Japanese prime minister arrives in Mex...
# 25             UK: Lloyd's chief undergoes U.S. grilling.
# 26       USA: War hero Colin Powell boosts Dole campaign.
# 27      GERMANY: German unions split on tactics in ret...
# 28      UK: British FTSE index closes at record 3,883 ...
# 29            UK: Trocadero expects tripling of revenues.
# ...                                                   ...
# 804384  USA: U.S.-based radio says broadcasts to China...
# 804385                  USA: TABLE - Wet Seal Q2 results.
# 804386  USA: U.S. spot resids mostly hold with firm ga...
# 804387  USA: Akorn completes relocation of offices to ...
# 804388         USA: TABLE - Longs Drug Stores Q2 results.
# 804389  USA: TABLE - Marvel Entertainment Q2 loss widens.
# 804390  USA: Dell earnings double in latest quarter, b...
# 804391    USA: Versant begins search for chief executive.
# 804392    USA: Ameritech to review FCC order, may refile.
# 804393  USA: Blue-chip stocks surge after Fed holds ra...
# 804394  USA: Extra Colo. River flows lift power output...
# 804395  USA: NYMEX Hub natgas ends up sharply on firme...
# 804396  USA: American Airlines starts new US-Mexico ro...
# 804397  USA: Minnesota official sees low odds for Twin...
# 804398  USA: Medtronic profits bolstered by ICD sales ...
# 804399  USA: ValuJet crash could have been avoided-U.S...
# 804400  USA: IMF board to discuss Thai loan package on...
# 804401  USA: No date yet for new Turkey-IMF talks-IMF ...
# 804402  USA: Koch Oil raises U.S. posted crude oil 25 ...
# 804403  USA: Texas abuse tape spurs unease over privat...
# 804404   USA: Beard Co to post $10.95 mln gain from sale.
# 804405  USA: Teamsters-UPS deal a boost to U.S. labor ...
# 804406   USA: Dell Q2 earnings double, topping estimates.
# 804407  USA: U.S. Spring/White Wheat - Fields drying o...
# 804408    USA: Jacor buys Cleveland sports radio station.
# 804409         USA: Icahn seeks three Panaco board seats.
# 804410                          USA: NYSE Unavailables -.
# 804411  USA: Tribe drops bid to stop Detroit casino pl...
# 804412              USA: Liuski names new president, CFO.
# 804413     USA: Export Business - Grain/oilseeds complex.
#
# [804414 rows x 7 columns]

# %%
newTitle = dataset.headline.str.replace('[^a-zA-Z ]', '')

# %%
newTitle[0:100]
# Out:
# 0     Recovery excitement brings Mexican markets to ...
# 1       Chrysler plans new investments in Latin America
# 2            CompuServe reports loss cutting work force
# 3            CompuServe reports loss cutting work force
# 4                 Planet Hollywood launches credit card
# 5     Hog prices tumble as supplies increase cocoa g...
# 6     Blue chips end up as Fed keeps interest rates ...
# 7      Sprint to offer consumer Internet access service
# 8                           Backtoschool spending is up
# 9     Kansas Arizona add to suits against tobacco firms
# 10      Chains may raise prices after minimum wage hike
# 11    Blue chips end up as Fed keeps interest rates ...
# 12       US Federal Reserve holds interest rates steady
# 13         Lloyds CEO questioned in recovery suit in US
# 14                 Most active stocks in Nasdaq trading
# 15                                NYSE closing averages
# 16       Ohio Blue Cross approves  mln ColumbiaHCA deal
# 17    War hero Colin Powell hits road with Dole camp...
# 18           Clinton signs law raising minimum wage to
# 19            Decision nears on Indiana tobacco lawsuit
# 20       Kansas files lawsuit against tobacco companies
# 21        Oil prices slip as refiners shop for bargains
# 22            Fed decides to keep interest rates steady
# 23               Japan EU may aid US in ag trade reform
# 24            Japanese prime minister arrives in Mexico
# 25                   Lloyds chief undergoes US grilling
# 26           War hero Colin Powell boosts Dole campaign
# 27    German unions split on tactics in retail pay t...
# 28          British FTSE index closes at record  points
# 29               Trocadero expects tripling of revenues
#                             ...
# 70               LONDON CURRENCY AND GOLD BULLION RATES
# 71       Complaints surge over UK demonic political ads
# 72       Londons Globe an experiment in theatre history
# 73                    BSkyB sees no corporation tax in
# 74                   BSkyB sees digital TV link with BT
# 75            Daily Mail buys  pct stake in study group
# 76          BSkyB says likely to take stake in Premiere
# 77       Lloyds braced for crucial US court case ruling
# 78          Silver hits twomonth peak gold edges higher
# 79                        MG joins fray to manage KEPIT
# 80           GrandMet plan Pillsbury briefing Wednesday
# 81         UK shares open steady look to M FOMC meeting
# 82                  BSkyB indicated lower after results
# 83                Orange loss widens but subscribers up
# 84               BSkyB full yr pretax profits jump  pct
# 85      Torontos stocks end stronger on resource issues
# 86               Workers on strike at Quaker Oats plant
# 87                    T  N half year shr falls div held
# 88        Polish consumer group takes CocaCola to court
# 89      Czech SPT falls back to earth pulls PSE with it
# 90    Russia Aug tax revenues meeting IMF goalsministry
# 91      Polish firms July earnings just up after weak H
# 92       Polish car sales rise  percent in seven months
# 93            Polish shares extend rally may lose steam
# 94    Slovak cbank moves failing to hit target  anal...
# 95    Russian securities body names three fund managers
# 96                  Czech Kavalier H gross profit rises
# 97             Pepsi to vanish from Venezuelan mkt soon
# 98             Chrysler to build  mln factory in Brazil
# 99       Australian govt pushes budget despite protests
# Name: headline, Length: 100, dtype: object

# %%
newTitle.to_csv('RCV1-title-queries.txt', sep=':')

# %% [markdown]
# ## 2. Running the queries in Terrier

# %% [markdown]
# #### BM25Classic
#
# My command - not using terrier passage:
#
#     bin/trec_terrier.sh -r -Dtrec.model=BM25
#                            -Dtrec.topics=/home/muntean/RCV1/data/RCV1-title-queries.txt
#                            -Dtrec.results=/home/muntean/RCV1/results
#                            -Dtrec.results.file=BM25-RCV1-all-title-queries.res
#
# 12:17:31.764 [main] INFO  o.t.a.batchquerying.TRECQuerying - Time to process query: 0.054
# 12:17:31.799 [main] INFO  o.t.a.batchquerying.TRECQuerying - Settings of Terrier written to /home/muntean/RCV1/results/BM25-RCV1-all-title-queries.res.settings
# 12:17:31.799 [main] INFO  o.t.a.batchquerying.TRECQuerying - Finished topics, executed 804406 queries in 66634.29 seconds, results written to /home/muntean/RCV1/results/BM25-RCV1-all-title-queries.res
# Time elapsed: 66637.903 seconds.

# %% [markdown]
# __We then run count-query-type-Terrier.py on the BM25-RCV1-all-title-queries.res file__

# %% [markdown]
# ```
# ('A', 225227)
# ('C', 152174)
# ('B', 221300)
# ('D', 105383)
# ```

# %% [markdown]
# ## 3. Running the queries on Elastic!
# #### JUST for BM25 so as to find query types
# An article has the following fields:
#
# ```{'_index': 'articles',
#     '_type': 'article',
#     '_id': '26',
#     '_score': 1.0,
#     '_source': {'title': "Survivor Upset Use of 'Eye of the Tiger' With Kim Davis",
#                 'media-type': 'Blog',
#                 'content': 'On Tuesday afternoon, Kim Davis, the Kentucky clerk whose imprisonment for not granting same-sex marriage licenses became a cause célèbre for the right, was released amid fanfare and a glowing introduction by Republican presidential hopeful Mike Huckabee.As Davis, her husband and attorney ...',
#                 'source': 'Latest News on One News Page [United States] - Top Headlines and News Videos',
#                 'published': '2015-09-10T03:00:15Z',
#                 'id': '7516303b-0db5-477d-9e5d-243a73865e39'}}```

# %%
es = Elasticsearch(['http://localhost/'], 
                    #http_auth=('elastic', 'bm25p'),
                    port=9200,
                    timeout=30
                    )

# %%
res = es.search(index="rcv1", 
                doc_type='article', 
                size=10, 
                body={"query": {
                        "match": {
                                "content": "Alex Wagner"
                        }}})

# [x['_source'] for x in res['hits']['hits']]
for r in res['hits']['hits'][:3]:
    print(r)
    print()
# Out:
# {'_index': 'rcv1', '_type': 'article', '_id': '23152', '_score': 14.878456, '_source': {'id': '26153', 'date': '1996-09-01', 'lang': 'en', 'title': 'ECUADOR: SOCCER-ECUADOR TAKE ANOTHER STEP TOWARDS FIRST WORLD CUP.', 'headline': 'SOCCER-ECUADOR TAKE ANOTHER STEP TOWARDS FIRST WORLD CUP.', 'content': "QUITO, Sept 1 (Ecuador) - Ecuador took another step towards their first World Cup when they beat Venezuela 1-0 on Sunday to record their third win in four qualifying games.\nCaptain Alex Aguinaga scored the winner in a game featuring the only two South American nations who have never played in the World Cup tournament.\nDespite three more precious points, Ecuador were jeered off the field by a 45,000 crowd who had expected a higher score against South American's weakest team who have taken only one point from their four games so far.\nAguinaga snapped up a rebound following a shot by Brazilian-born Gilson de Souza in the fourth minute but Ecuador were unable to add to their tally.\nEcuador, coached by Colombia's former national team boss Francisco Maturana, have already beaten Argentina at home in their impressive start and have a good chance of finishing in the top four of the nine-team group.\nBut they still have a long way to go and questions were asked when they lost 4-1 defeat by Chile in Santiago last month on their only venture outside Ecuador so far.\nEcuador - Carlos Morales; Wagner Rivera, Ivan Hurtado, Maximo Tenorio, Luis Capurro; Jorge Diaz (Alfonso Obregon, 79th minute), Hector Carabali, Alex Aguinaga, Jose Garcia (Angel Fernandez, 46th); Gilson de Souza, Eduardo Hurtado.\nVenezuela - Rafael Dudamel; Luis Filosa, William Gonzalez, Edson Tortolero, David Macintosh; Sergio Hernandez, Jess Valiente (Gabriel Urdaneta, 40th), Luis Vera, Gabriel Miranda; Juan Socorro (Luis Hernndez, 79th), Juan Garcia.", 'categories': ['GCAT', 'GSPO']}}
#
# {'_index': 'rcv1', '_type': 'article', '_id': '369710', '_score': 14.413828, '_source': {'id': '373602', 'date': '1997-02-12', 'lang': 'en', 'title': 'GERMANY: German plastics processing industry more upbeat.', 'headline': 'German plastics processing industry more upbeat.', 'content': 'The German plastics processing industry is slightly more upbeat for the 1997 business year, predicting stronger production and sales growth even though price pressures were seen hurting the industry\'s results.\nNorbert Wagner, head of the industry association Gesamtverband kunststoffverarbeitende Industrie (GKV), told journalists on Wednesday that sales would likely rise by 4.3 percent this year with production climbing by 3.5 percent.\nOn the other hand, Wagner said about one quarter of all German plastics processing groups would likely swing to losses in 1997 as intense price pressures were sure to impact results.\nReferring to former Volkswagen AG purchasing manager Jose Lopez de Arriortua, famous for pushing prices dramatically lower, Wagner said: "One Lopez left the industry, but some 100 little Lopezes have emerged."\nBut industry association members were slightly more upbeat than Wagner was, as 38 percent predicted improved results this year. This compares with only 24 percent who had predicted improved results for the 1996 business year.\nInvestments in 1997 were expected to remain at year-ago levels, at around three billion marks, Wagner said.\nSuffering under the effects of a soft first quarter last year, the industry posted total sales of around 65.8 billion marks, down 1.6 percent from 1995 levels, the group said.\nWagner explained that a surge in production in the second half of 1996 helped recover some ground lost when production dropped about 8.5 percent during the first quarter 1996.\nPrices droppped by only 0.8 percent, he added.\nWagner said the industry had largely completed its downsizing which meant that jobs, reduced by about 8,000 to 270,000 last year, would be secure for some time.\nIn fact the industry was encountering difficulties in filling available jobs with not all 1,000 trainee positions taken up.\n--Svea Herbst-Bayliss, Frankfurt Newsroom, +49 69 756525', 'categories': ['C21', 'C31', 'CCAT']}}
#
# {'_index': 'rcv1', '_type': 'article', '_id': '285299', '_score': 14.373821, '_source': {'id': '289017', 'date': '1997-01-06', 'lang': 'en', 'title': 'USA: SurVivaLink names Wagner chief executive.', 'headline': 'SurVivaLink names Wagner chief executive.', 'content': 'SurVivaLink Corp said Monday it has named its president and chief operating officer Mark Wagner as chief executive officer.\nWagner replaces Byron Gilman, who will remain chairman and assume the title and duties of chief technical officer. \nWagner joined SurVivaLink in September 1996.\nSurVivaLink provides automated external defribillators used to treat victims of sudden cardiac arrest.\n((--Chicago newsdesk, 312-408-8787))', 'categories': ['C41', 'C411', 'CCAT']}}

# %% [markdown]
# __We then run count-query-type-Elastic.py on the BM25-RCV1-all-title-queries.res file__

# %% [markdown]
# ```
# ('A', 238580)
# ('C', 152506)
# ('B', 228059)
# ('D', 103161)
# ```

# %% [markdown]
# # 4. Generate samples (10.000) for queries on intersection between Terrier and Elastic - Global
#
# See notebook: http://146.48.82.32:9999/notebooks/RCV1/notebooks/Create%20RCV1%20final%20query%20set%20from%20Terrier%20and%20Elastic%20on%20BM25.ipynb
